# %% [markdown]
# #QUESTIONS BASED ON PANDAS SERIES

# %%
# Q1
import pandas as pd

Series1 = pd.Series([100, 200, 300, 400, 500], index=['A','B','C','D','E'])
Series2 = Series1 * 2

print(Series1)
print(Series2)
# Out:
# A    100
# B    200
# C    300
# D    400
# E    500
# dtype: int64
# A     200
# B     400
# C     600
# D     800
# E    1000
# dtype: int64

# %% [markdown]
# # Q2
# ## ANSWER:
# ### (a) A Series object is size mutable → False
# ###  (b) A DataFrame object is value mutable → True

# %%
# Q3
import pandas as pd

Series1 = pd.Series([700,700,700,700,700], index=[200,201,202,203,204])
print(Series1)
# Out:
# 200    700
# 201    700
# 202    700
# 203    700
# 204    700
# dtype: int64

# %%
# Q4
import pandas as pd

s = pd.Series([95,89,92,95], index=['IP','Physics','Chemistry','Math'])

# i
print(s['IP'])

# ii
print(s + 10)
# Out:
# 95
# IP           105
# Physics       99
# Chemistry    102
# Math         105
# dtype: int64

# %%
# Q5
import pandas as pd

s = pd.Series([50000,65890,56780,89000,77900],
              index=['QTR1','QTR2','QTR3','QTR4','QTR5'])

print(s)
# Out:
# QTR1    50000
# QTR2    65890
# QTR3    56780
# QTR4    89000
# QTR5    77900
# dtype: int64

# %%
# Q6
import pandas as pd

S1 = pd.Series(data=[31,41,51])

print(S1>40)
print(S1[S1>40])
# Out:
# 0    False
# 1     True
# 2     True
# dtype: bool
# 1    41
# 2    51
# dtype: int64

# %%
# Q7
import pandas as pd

S1 = pd.Series([39,41,42,44], index=['A','B','C','D'])
S2 = pd.Series([10,10,10,10], index=['A','B','D','F'])

# a
print(S1[:2] * 100)

# b
print(S1 * S2)

# c
print(S2[::-1] * 10)
# Out:
# A    3900
# B    4100
# dtype: int64
# A    390.0
# B    410.0
# C      NaN
# D    440.0
# F      NaN
# dtype: float64
# F    100
# D    100
# B    100
# A    100
# dtype: int64

# %%
# Q8
import pandas as pd

S1 = pd.Series([10,20,30,40], index=['A','B','C','D'])
S2 = pd.Series([5,4,6,8], index=['A','B','C','D'])

print(S1 * S2)
# Out:
# A     50
# B     80
# C    180
# D    320
# dtype: int64

# %%
# Q9
import pandas as pd

subject = pd.Series([75,78,82,86],
                    index=['ENGLISH','HINDI','MATHS','SCIENCE'])

print(subject)
# Out:
# ENGLISH    75
# HINDI      78
# MATHS      82
# SCIENCE    86
# dtype: int64

# %%
# Q10
import pandas as pd

company = pd.Series([350,200,800,150],
                    index=['TCS','Reliance','L&T','Wipro'])

# i
print(company[company > 250])

# ii
company.name = "Profit"
print(company)
# Out:
# TCS    350
# L&T    800
# dtype: int64
# TCS         350
# Reliance    200
# L&T         800
# Wipro       150
# Name: Profit, dtype: int64

# %%
# Q11
a = [10,20,25,50]

import pandas as pd
b = pd.Series([10,20,25,50])

print(a*2)
print(b*2)
# Out:
# [10, 20, 25, 50, 10, 20, 25, 50]
# 0     20
# 1     40
# 2     50
# 3    100
# dtype: int64

# %%
# Q12
# Correct option is (a) print(Sample.tail(3))

import pandas as pd

Sample = pd.Series([10, 20, 30, 40, 50, 60, 70])

result = Sample.tail(3)

print(result)
# Out:
# 4    50
# 5    60
# 6    70
# dtype: int64

# %%
# Q13
import pandas as pd

s = pd.Series(6, index=range(0,5))
print(s)
# Out:
# 0    6
# 1    6
# 2    6
# 3    6
# 4    6
# dtype: int64

# %%
# Q14

import pandas as pd
s1 = pd.Series([10, 20, 30, 40, 50, 60, 70, 80])

result = s1[3:6]
print(result)
# Out:
# 3    40
# 4    50
# 5    60
# dtype: int64

# %%
# Q15
import pandas as pd
import numpy as np

s = pd.Series(np.arange(10,50,10))
print(s)
print(s.ndim)
print(s.shape)
print(len(s))
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
# 1
# (4,)
# 4

# %%
# Q16
import pandas as pd
import numpy as np

s = pd.Series(np.random.randint(10,21,10))
print(s)
# Out:
# 0    18
# 1    16
# 2    10
# 3    13
# 4    20
# 5    19
# 6    10
# 7    20
# 8    16
# 9    11
# dtype: int64

# %%
# Q17
import pandas as pd
import numpy as np

s = pd.Series([4.0,5.0,7.0,np.nan,1.0,10.0])

# i
print(s + 1)

# ii
print(s.fillna(0))
# Out:
# 0     5.0
# 1     6.0
# 2     8.0
# 3     NaN
# 4     2.0
# 5    11.0
# dtype: float64
# 0     4.0
# 1     5.0
# 2     7.0
# 3     0.0
# 4     1.0
# 5    10.0
# dtype: float64

# %%
# Q18
import pandas as pd

data = {'one':'a','two':'b','three':'c'}
s = pd.Series(data)

print(s)
print(s.size)
# Out:
# one      a
# two      b
# three    c
# dtype: object
# 3

# %%
# Q19
import pandas as pd

S1 = pd.Series([2,4,6,8])
print(S1)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# dtype: int64

# %%
# Q20
import pandas as pd

s2 = pd.Series(["i","am","a","student"])
print(s2)
# Out:
# 0          i
# 1         am
# 2          a
# 3    student
# dtype: object

# %%
# QUESTION 1 - Employee DataFrame

emp = pd.DataFrame({
    "Name": ["Atul","Raj","Darpan","Anmol","Piyush"],
    "Age": [25,30,23,22,32],
    "Designation": ["Manager","Clerk","Analyst","Clerk","Manager"],
    "Salary": [56000,25000,35000,28000,58000],
    "Bonus": [15000,7000,9000,13000,12000]
}, index=["E101","E102","E103","E104","E105"])


# ---------------- a ----------------
emp["City"] = None
emp["Shift"] = None

emp.loc["E106"] = ["GEET", 24, "Analyst", 70000, 15000, "Tilak Nagar", "Morning"]


# ---------------- b ----------------
emp["Shift"] = "Morning"


# ---------------- c ----------------
print("\nYoungest Employee:")
print(emp[emp["Age"] == emp["Age"].min()])


# ---------------- d ----------------
print("\nAll Clerks:")
print(emp[emp["Designation"] == "Clerk"])


# ---------------- e ----------------
print("\nAverage Bonus:")
print(emp["Bonus"].mean())


# ---------------- f ----------------

print("\nTotal Salary:")
print(emp["Salary"].sum())


# ---------------- g ----------------
emp.loc["E101":"E105","City"] = [
    "Janak Puri",
    "Tilak Nagar",
    "Shiv Nagar",
    "Vikas Puri",
    "Janak Puri"
]


# ---------------- h ----------------
emp = emp.drop(["E103","E105"])


# ---------------- i ----------------
emp = emp.rename(columns={"Bonus": "Incentive"})


print("\nFinal DataFrame:")
print(emp)
# Out:
# Youngest Employee:
#        Name  Age Designation  Salary  Bonus  City    Shift
# E104  Anmol   22       Clerk   28000  13000  None  Morning
#
# All Clerks:
#        Name  Age Designation  Salary  Bonus  City    Shift
# E102    Raj   30       Clerk   25000   7000  None  Morning
# E104  Anmol   22       Clerk   28000  13000  None  Morning
#
# Average Bonus:
# 11833.333333333334
#
# Total Salary:
# 272000
#
# Final DataFrame:
#        Name  Age Designation  Salary  Incentive         City    Shift
# E101   Atul   25     Manager   56000      15000   Janak Puri  Morning
# E102    Raj   30       Clerk   25000       7000  Tilak Nagar  Morning
# E104  Anmol   22       Clerk   28000      13000   Vikas Puri  Morning
# E106   GEET   24     Analyst   70000      15000  Tilak Nagar  Morning

# %%
# QUESTION 2: DataFrame “data”

import pandas as pd

data = pd.DataFrame({
    "Count":[15,20,25,35],
    "Price":[250,200,600,900]
}, index=["Pencil","Pen","Eraser","Scale"])

print(data)

# a) Change Eraser count to 15
data.loc["Eraser","Count"] = 15

# b) Rename index Scale → Wooden Scale
data = data.rename(index={"Scale":"Wooden Scale"})

# c) Change row labels
data.index = ["Product 1","Product 2","Product 3","Product 4"]

# d) Change column names
data.columns = ["Discount","Total"]

# e) Add new row Product 5
data.loc["Product 5"] = [10,100]

# f) Create Products dataframe without Total column
Products = data.drop(columns=["Total"])

print(data)
print(Products)
# Out:
#         Count  Price
# Pencil     15    250
# Pen        20    200
# Eraser     25    600
# Scale      35    900
#            Discount  Total
# Product 1        15    250
# Product 2        20    200
# Product 3        15    600
# Product 4        35    900
# Product 5        10    100
#            Discount
# Product 1        15
# Product 2        20
# Product 3        15
# Product 4        35
# Product 5        10

# %%
# QUESTION 3: Production DataFrame

import pandas as pd
import numpy as np

prod = pd.DataFrame({
    "Fruits":[44,11950,7152,140169,7830,113],
    "Pulses":[23,818,33,3184,931,1],
    "Rice":[814,1930,11586,13574,7452,2604],
    "Wheat":[5,2737,16440,30056,np.nan,np.nan]
}, index=["Tripura","Gujrat","Punjab","UP","AP","Kerala"])

print(prod)

# a) Total production for each state
print(prod.sum(axis=1))

# b) Total production for each item
print(prod.sum(axis=0))

# c) How many states produce Wheat
print(prod["Wheat"].count())
# Out:
#          Fruits  Pulses   Rice    Wheat
# Tripura      44      23    814      5.0
# Gujrat    11950     818   1930   2737.0
# Punjab     7152      33  11586  16440.0
# UP       140169    3184  13574  30056.0
# AP         7830     931   7452      NaN
# Kerala      113       1   2604      NaN
# Tripura       886.0
# Gujrat      17435.0
# Punjab      35211.0
# UP         186983.0
# AP          16213.0
# Kerala       2718.0
# dtype: float64
# Fruits    167258.0
# Pulses      4990.0
# Rice       37960.0
# Wheat      49238.0
# dtype: float64
# 4
